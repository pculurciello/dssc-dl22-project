# %%
import os
import random

file_dir = os.path.join(os.getcwd(), 'barks_10s')
barks = os.listdir(file_dir)

for i in range(len(barks)):
    bark = random.choices(barks)
    barks.remove(bark[0])
    print(bark)
# Out:
# ['sample_roll_18.wav']
# ['sample_stretch_61.wav']
# ['sample_noise_89.wav']
# ['bark_22.wav']
# ['sample_roll_102.wav']
# ['sample_stretch_39.wav']
# ['sample_noise_41.wav']
# ['sample_stretch_103.wav']
# ['sample_roll_85.wav']
# ['bark_41.wav']
# ['bark_112.wav']
# ['sample_noise_23.wav']
# ['sample_stretch_83.wav']
# ['sample_noise_62.wav']
# ['sample_noise_108.wav']
# ['sample_roll_114.wav']
# ['sample_noise_109.wav']
# ['sample_stretch_42.wav']
# ['sample_stretch_41.wav']
# ['sample_roll_88.wav']
# ['bark_45.wav']
# ['sample_noise_34.wav']
# ['bark_95.wav']
# ['bark_98.wav']
# ['sample_stretch_98.wav']
# ['sample_noise_87.wav']
# ['sample_noise_64.wav']
# ['sample_noise_78.wav']
# ['sample_roll_59.wav']
# ['sample_roll_90.wav']
# ['sample_stretch_93.wav']
# ['sample_stretch_74.wav']
# ['bark_50.wav']
# ['bark_78.wav']
# ['sample_roll_23.wav']
# ['bark_32.wav']
# ['bark_109.wav']
# ['sample_roll_32.wav']
# ['sample_noise_63.wav']
# ['bark_57.wav']
# ['bark_76.wav']
# ...
